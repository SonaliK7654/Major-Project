# %% [markdown]
# # Finding the MRI brain tumor detection dataset

# %% [markdown]
# Let's find the dataset in this link: https://www.kaggle.com/navoneel/brain-mri-images-for-brain-tumor-detection

# %% [markdown]
# # Import packages

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, ConcatDataset
import glob
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score
import random
import cv2
import sys

# %% [markdown]
# # Image Reading

# %%
tumor = []
healthy = []
for f in glob.iglob("./brain_tumor_dataset/yes/*.jpg"):
    img = cv2.imread(f)
    img = cv2.resize(img,(128,128))
    b, g, r = cv2.split(img)
    img = cv2.merge([r,g,b])
    tumor.append(img)

for f in glob.iglob("./brain_tumor_dataset/no/*.jpg"):
    img = cv2.imread(f)
    img = cv2.resize(img,(128,128)) 
    b, g, r = cv2.split(img)
    img = cv2.merge([r,g,b])
    healthy.append(img)

# %%
healthy = np.array(healthy)
tumor = np.array(tumor)
All = np.concatenate((healthy, tumor))

# %%
healthy.shape
# Out:
# (91, 128, 128, 3)

# %%
tumor.shape
# Out:
# (154, 128, 128, 3)

# %%
np.random.choice(10, 5, replace=False)
# Out:
# array([8, 4, 6, 0, 7])

# %% [markdown]
# # MRI Image Visualization

# %%
def plot_random(healthy, tumor, num=5):
    healthy_imgs = healthy[np.random.choice(healthy.shape[0], num, replace=False)]
    tumor_imgs = tumor[np.random.choice(tumor.shape[0], num, replace=False)]
    
    plt.figure(figsize=(16,9))
    for i in range(num):
        plt.subplot(1, num, i+1)
        plt.title('healthy')
        plt.imshow(healthy_imgs[i])
        
    plt.figure(figsize=(16,9))
    for i in range(num):
        plt.subplot(1, num, i+1)
        plt.title('tumor')
        plt.imshow(tumor_imgs[i])

# %%
plot_random(healthy, tumor, num=5)

# %% [markdown]
# # Creating Torch Dataset Class

# %% [markdown]
# # Pytorch's Abstract Dataset Class

# %%
class Dataset(object):
    """An abstract class representing a Dataset.

    All other datasets should subclass it. All subclasses should override
    ``__len__``, that provides the size of the dataset, and ``__getitem__``,
    supporting integer indexing in range from 0 to len(self) exclusive.
    """

    def __getitem__(self, index):
        raise NotImplementedError

    def __len__(self):
        raise NotImplementedError

    def __add__(self, other):
        return ConcatDataset([self, other])

# %% [markdown]
# # Creating MRI cutom dataset class

# %%
class MRI(Dataset):
    def __init__(self):
        
        tumor = []
        healthy = []
        # cv2 - It reads in BGR format by default
        for f in glob.iglob("./brain_tumor_dataset/yes/*.jpg"):
            img = cv2.imread(f)
            img = cv2.resize(img,(128,128)) # I can add this later in the boot-camp for more adventure
            b, g, r = cv2.split(img)
            img = cv2.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0],img.shape[1])) # otherwise the shape will be (h,w,#channels)
            tumor.append(img)

        for f in glob.iglob("./brain_tumor_dataset/no/*.jpg"):
            img = cv2.imread(f)
            img = cv2.resize(img,(128,128)) 
            b, g, r = cv2.split(img)
            img = cv2.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0],img.shape[1]))
            healthy.append(img)

        # our images
        tumor = np.array(tumor,dtype=np.float32)
        healthy = np.array(healthy,dtype=np.float32)
        
        # our labels
        tumor_label = np.ones(tumor.shape[0], dtype=np.float32)
        healthy_label = np.zeros(healthy.shape[0], dtype=np.float32)
        
        # Concatenates
        self.images = np.concatenate((tumor, healthy), axis=0)
        self.labels = np.concatenate((tumor_label, healthy_label))
        
    def __len__(self):
        return self.images.shape[0]
    
    def __getitem__(self, index):
        
        sample = {'image': self.images[index], 'label':self.labels[index]}
        
        return sample
    
    def normalize(self):
        self.images = self.images/255.0

# %%
mri_dataset = MRI()
mri_dataset.normalize()

# %% [markdown]
# # Creating a dataloader

# %%
# One way of iterating
names={0:'Heathy', 1:'Tumor'}
dataloader = DataLoader(mri_dataset, shuffle=True)
for i, sample in enumerate(dataloader):
    img = sample['image'].squeeze()
    img = img.reshape((img.shape[1], img.shape[2], img.shape[0]))
    plt.title(names[sample['label'].item()])
    plt.imshow(img)
    plt.show()
    if i == 5:
        break

# %% [markdown]
# # Create a model

# %%
import torch.nn as nn
import torch.nn.functional as F

class CNN(nn.Module):
    def __init__(self):
        super(CNN,self).__init__()
        self.cnn_model = nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5),
        nn.Tanh(),
        nn.AvgPool2d(kernel_size=2, stride=5),
        nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5),
        nn.Tanh(),
        nn.AvgPool2d(kernel_size=2, stride=5))
        
        self.fc_model = nn.Sequential(
        nn.Linear(in_features=256, out_features=120),
        nn.Tanh(),
        nn.Linear(in_features=120, out_features=84),
        nn.Tanh(),
        nn.Linear(in_features=84, out_features=1))
        
    def forward(self, x):
        x = self.cnn_model(x)
        x = x.view(x.size(0), -1)
        x = self.fc_model(x)
        x = F.sigmoid(x)
        
        return x

# %% [markdown]
# # Some Basics of Training and Evaluation in Pytorch

# %% [markdown]
# # model.eval()

# %% [markdown]
# Used particularly for inference NOTHING to DO with gradients!!!
# changes the forward() behaviour of the module it is called up on eg, it disables dropout and has batch norm use the entire population statistics. This is necessary for inference

# %%
mri_dataset = MRI()
mri_dataset.normalize()
device = torch.device('cpu:0')
model = CNN().to(device)

# %%
dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=False)

# %%
model.eval()
outputs = []
y_true = []
with torch.no_grad():
    for D in dataloader:
        image = D['image'].to(device)
        label = D['label'].to(device)

        y_hat = model(image)

        outputs.append(y_hat.cpu().detach().numpy())
        y_true.append(label.cpu().detach().numpy())

# %%
outputs = np.concatenate( outputs, axis=0 ).squeeze()
y_true = np.concatenate( y_true, axis=0 ).squeeze()

# %%
def threshold(scores,threshold=0.50, minimum=0, maximum = 1.0):
    x = np.array(list(scores))
    x[x >= threshold] = maximum
    x[x < threshold] = minimum
    return x

# %%
accuracy_score(y_true, threshold(outputs))
# Out:
# 0.37142857142857144

# %%
# a better confusion matrix
import seaborn as sns

plt.figure(figsize=(16,9))
cm = confusion_matrix(y_true, threshold(outputs))
ax= plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax, annot_kws={"size": 20})

# labels, title and ticks
ax.set_xlabel('Predicted labels', fontsize=20)
ax.set_ylabel('True labels', fontsize=20) 
ax.set_title('Confusion Matrix', fontsize=20)
ax.xaxis.set_ticklabels(['Healthy','Tumor'], fontsize=20)
ax.yaxis.set_ticklabels(['Tumor','Healthy'], fontsize=20)
# Out:
# [Text(0, 0.5, 'Tumor'), Text(0, 1.5, 'Healthy')]

# %%
plt.figure(figsize=(16,9))
plt.plot(outputs)
plt.axvline(x=len(tumor), color='r', linestyle='--')
plt.grid()

# %%
eta = 0.0001
EPOCH = 400
optimizer = torch.optim.Adam(model.parameters(), lr=eta)
dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=True)
model.train()
# Out:
# CNN(
#   (cnn_model): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#     (1): Tanh()
#     (2): AvgPool2d(kernel_size=2, stride=5, padding=0)
#     (3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#     (4): Tanh()
#     (5): AvgPool2d(kernel_size=2, stride=5, padding=0)
#   )
#   (fc_model): Sequential(
#     (0): Linear(in_features=256, out_features=120, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=120, out_features=84, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=84, out_features=1, bias=True)
#   )
# )

# %%
for epoch in range(1, EPOCH):
    losses = []
    for D in dataloader:
        optimizer.zero_grad()
        data = D['image'].to(device)
        label = D['label'].to(device)
        y_hat = model(data)
        # define loss function
        error = nn.BCELoss() 
        loss = torch.sum(error(y_hat.squeeze(), label))
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    if (epoch+1) % 10 == 0:
        print('Train Epoch: {}\tLoss: {:.6f}'.format(epoch+1, np.mean(losses)))
# Out:
# Train Epoch: 10	Loss: 0.623353
# Train Epoch: 20	Loss: 0.596503
# Train Epoch: 30	Loss: 0.561741
# Train Epoch: 40	Loss: 0.550702
# Train Epoch: 50	Loss: 0.534734
# Train Epoch: 60	Loss: 0.514748
# Train Epoch: 70	Loss: 0.502192
# Train Epoch: 80	Loss: 0.493302
# Train Epoch: 90	Loss: 0.470851
# Train Epoch: 100	Loss: 0.452247
# Train Epoch: 110	Loss: 0.439508
# Train Epoch: 120	Loss: 0.432317
# Train Epoch: 130	Loss: 0.415724
# Train Epoch: 140	Loss: 0.396968
# Train Epoch: 150	Loss: 0.392310
# Train Epoch: 160	Loss: 0.369124
# Train Epoch: 170	Loss: 0.365547
# Train Epoch: 180	Loss: 0.365876
# Train Epoch: 190	Loss: 0.330783
# Train Epoch: 200	Loss: 0.320187
# Train Epoch: 210	Loss: 0.304532
# Train Epoch: 220	Loss: 0.295748
# Train Epoch: 230	Loss: 0.269451
# Train Epoch: 240	Loss: 0.247211
# Train Epoch: 250	Loss: 0.245577
# Train Epoch: 260	Loss: 0.225451
# Train Epoch: 270	Loss: 0.216263
# Train Epoch: 280	Loss: 0.199398
# Train Epoch: 290	Loss: 0.178884
# Train Epoch: 300	Loss: 0.166382
# Train Epoch: 310	Loss: 0.145430
# Train Epoch: 320	Loss: 0.126332
# Train Epoch: 330	Loss: 0.126332
# Train Epoch: 340	Loss: 0.100706
# Train Epoch: 350	Loss: 0.091581
# Train Epoch: 360	Loss: 0.071199
# Train Epoch: 370	Loss: 0.062787
# Train Epoch: 380	Loss: 0.050661
# Train Epoch: 390	Loss: 0.045457
# Train Epoch: 400	Loss: 0.035780

# %% [markdown]
# # Evaluate a smart model

# %%
model.eval()
dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=False)
outputs=[]
y_true = []
with torch.no_grad():
    for D in dataloader:
        image =  D['image'].to(device)
        label = D['label'].to(device)
        
        y_hat = model(image)
        
        outputs.append(y_hat.cpu().detach().numpy())
        y_true.append(label.cpu().detach().numpy())
        
outputs = np.concatenate( outputs, axis=0 )
y_true = np.concatenate( y_true, axis=0 )

# %%
accuracy_score(y_true, threshold(outputs))
# Out:
# 1.0

# %%
cm = confusion_matrix(y_true, threshold(outputs))
plt.figure(figsize=(16,9))

ax= plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['Tumor','Healthy'])
ax.yaxis.set_ticklabels(['Tumor','Healthy'])
# Out:
# [Text(0, 0.5, 'Tumor'), Text(0, 1.5, 'Healthy')]

# %%
plt.figure(figsize=(16,9))
plt.plot(outputs)
plt.axvline(x=len(tumor), color='r', linestyle='--')
plt.grid()

# %% [markdown]
# # Visualising the Feature Maps of the Convolutional Filters

# %%
model
# Out:
# CNN(
#   (cnn_model): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#     (1): Tanh()
#     (2): AvgPool2d(kernel_size=2, stride=5, padding=0)
#     (3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#     (4): Tanh()
#     (5): AvgPool2d(kernel_size=2, stride=5, padding=0)
#   )
#   (fc_model): Sequential(
#     (0): Linear(in_features=256, out_features=120, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=120, out_features=84, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=84, out_features=1, bias=True)
#   )
# )

# %%
no_of_layers = 0
conv_layers = []

# %%
model_children = list(model.children())
model_children
# Out:
# [Sequential(
#    (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#    (1): Tanh()
#    (2): AvgPool2d(kernel_size=2, stride=5, padding=0)
#    (3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#    (4): Tanh()
#    (5): AvgPool2d(kernel_size=2, stride=5, padding=0)
#  ),
#  Sequential(
#    (0): Linear(in_features=256, out_features=120, bias=True)
#    (1): Tanh()
#    (2): Linear(in_features=120, out_features=84, bias=True)
#    (3): Tanh()
#    (4): Linear(in_features=84, out_features=1, bias=True)
#  )]

# %%
for child in model_children:
    if type(child) == nn.Sequential:
        for layer in child.children():
            if type(layer) == nn.Conv2d:
                no_of_layers += 1
                conv_layers.append(layer)

# %%
conv_layers
# Out:
# [Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1)),
#  Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))]

# %%
img = mri_dataset[100]['image']
plt.imshow(img.reshape(128,128,3))

# %%
img = torch.from_numpy(img).to(device)

# %%
img.shape
# Out:
# torch.Size([3, 128, 128])

# %%
img = img.unsqueeze(0)
img.shape
# Out:
# torch.Size([1, 3, 128, 128])

# %%
results = [conv_layers[0](img)]
for i in range(1, len(conv_layers)):
    results.append(conv_layers[i](results[-1]))
outputs = results

# %%
for num_layer in range(len(outputs)):
    plt.figure(figsize=(50, 10))
    layer_viz = outputs[num_layer].squeeze()
    print("Layer ",num_layer+1)
    for i, f in enumerate(layer_viz):
        plt.subplot(2, 8, i + 1)
        plt.imshow(f.detach().cpu().numpy())
        plt.axis("off")
    plt.show()
    plt.close()
# Out:
# Layer  1
# Layer  2

# %% [markdown]
# # Preparing a validation set: We need to change the MRI dataset slightly!

# %%
from sklearn.model_selection import train_test_split

# %%
class MRI(Dataset):
    
    def __init__(self):
        
        # Variables to hold the Training data and Validation data
        self.X_train, self.y_train, self.X_val, self.y_val = None, None, None, None
        
        # A variable to determine if we are interested in retrieving the training OR the validation data
        self.mode = 'train'
        
        tumor = []
        healthy = []
        # cv2 - It reads in BGR format by default
        for f in glob.iglob("./brain_tumor_dataset/yes/*.jpg"):
            img = cv2.imread(f)
            img = cv2.resize(img,(128,128)) # I can add this later in the boot-camp for more adventure
            b, g, r = cv2.split(img)
            img = cv2.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0],img.shape[1])) # otherwise the shape will be (h,w,#channels)
            tumor.append(img)

        for f in glob.iglob("./brain_tumor_dataset/no/*.jpg"):
            img = cv2.imread(f)
            img = cv2.resize(img,(128,128)) 
            b, g, r = cv2.split(img)
            img = cv2.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0],img.shape[1]))
            healthy.append(img)
              # our images
        tumor = np.array(tumor,dtype=np.float32)
        healthy = np.array(healthy,dtype=np.float32)
        
        # our labels
        tumor_label = np.ones(tumor.shape[0], dtype=np.float32)
        healthy_label = np.zeros(healthy.shape[0], dtype=np.float32)
        
        # Concatenates
        self.images = np.concatenate((tumor, healthy), axis=0)
        self.labels = np.concatenate((tumor_label, healthy_label))
    
    # Define a function that would separate the data into Training and Validation sets
    def train_val_split(self):
        self.X_train, self.X_val, self.y_train, self.y_val = \
        train_test_split(self.images, self.labels, test_size=0.20, random_state=42)
        
    def __len__(self):
        # Use self.mode to deetrmine whether train or val data is of interest
        if self.mode == 'train':
            return self.X_train.shape[0]
        elif self.mode == 'val':
            return self.X_val.shape[0]

    def __getitem__(self, idx):
        # Use self.mode to deetrmine whether train or val data is of interest
        if self.mode== 'train':
            sample = {'image': self.X_train[idx], 'label': self.y_train[idx]}
        
        elif self.mode== 'val':
            sample = {'image': self.X_val[idx], 'label': self.y_val[idx]}
        
        return sample
    
    def normalize(self):
        self.images = self.images/255.0

# %%
mri_dataset = MRI()
mri_dataset.normalize()
mri_dataset.train_val_split()

# %%
train_dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=True)
val_dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=False)

# %%
device = torch.device("cuda:0")
model = CNN().to(device)

# %%
eta=0.0001
optimizer = torch.optim.Adam(model.parameters(), lr=eta)

# %%
# keep track of epoch losses
epoch_train_loss = []
epoch_val_loss = []

# %%
for epoch in range(1,600):
    train_losses = []
    # train for the current epoch
    model.train()
    mri_dataset.mode = 'train'
    for D in train_dataloader:
        # Train the model
        optimizer.zero_grad()
        data = D['image'].to(device)
        label = D['label'].to(device)
        
        y_hat = model(data)
        error = nn.BCELoss()
        loss = torch.sum(error(y_hat.squeeze(), label))
        loss.backward()
        optimizer.step()
        train_losses.append(loss.item())
    
    epoch_train_loss.append(np.mean(train_losses))
    
    # validate for the current epoch
    val_losses = []
    model.eval()
    
    mri_dataset.mode = 'val'
    
    with torch.no_grad():
        for D in val_dataloader:            
            data = D['image'].to(device)
            label = D['label'].to(device)
            y_hat = model(data)
            error = nn.BCELoss()
            loss = torch.sum(error(y_hat.squeeze(), label))
            val_losses.append(loss.item())
    
    epoch_val_loss.append(np.mean(val_losses))
    
    if (epoch+1) % 10 == 0:
        print('Train Epoch: {}\tTrain Loss: {:.6f}\tVal Loss: {:.6f}'.format(epoch+1, np.mean(train_losses),np.mean(val_losses)))
# Out:
# Train Epoch: 10	Train Loss: 0.653606	Val Loss: 0.596572
# Train Epoch: 20	Train Loss: 0.607382	Val Loss: 0.575429
# Train Epoch: 30	Train Loss: 0.528020	Val Loss: 0.525996
# Train Epoch: 40	Train Loss: 0.491803	Val Loss: 0.527987
# Train Epoch: 50	Train Loss: 0.516515	Val Loss: 0.533479
# Train Epoch: 60	Train Loss: 0.553220	Val Loss: 0.529131
# Train Epoch: 70	Train Loss: 0.489589	Val Loss: 0.550690
# Train Epoch: 80	Train Loss: 0.551856	Val Loss: 0.555170
# Train Epoch: 90	Train Loss: 0.547230	Val Loss: 0.557635
# Train Epoch: 100	Train Loss: 0.458950	Val Loss: 0.553879
# Train Epoch: 110	Train Loss: 0.519810	Val Loss: 0.555401
# Train Epoch: 120	Train Loss: 0.427822	Val Loss: 0.585905
# Train Epoch: 130	Train Loss: 0.422335	Val Loss: 0.593119
# Train Epoch: 140	Train Loss: 0.424237	Val Loss: 0.631885
# Train Epoch: 150	Train Loss: 0.397391	Val Loss: 0.639833
# Train Epoch: 160	Train Loss: 0.446344	Val Loss: 0.668838
# Train Epoch: 170	Train Loss: 0.379710	Val Loss: 0.684871
# Train Epoch: 180	Train Loss: 0.391843	Val Loss: 0.695788
# Train Epoch: 190	Train Loss: 0.368472	Val Loss: 0.703942
# Train Epoch: 200	Train Loss: 0.385580	Val Loss: 0.721468
# Train Epoch: 210	Train Loss: 0.338847	Val Loss: 0.722633
# Train Epoch: 220	Train Loss: 0.309659	Val Loss: 0.745332
# Train Epoch: 230	Train Loss: 0.358913	Val Loss: 0.726373
# Train Epoch: 240	Train Loss: 0.272174	Val Loss: 0.698251
# Train Epoch: 250	Train Loss: 0.331451	Val Loss: 0.745960
# Train Epoch: 260	Train Loss: 0.321948	Val Loss: 0.719926
# Train Epoch: 270	Train Loss: 0.282038	Val Loss: 0.748239
# Train Epoch: 280	Train Loss: 0.217505	Val Loss: 0.746527
# Train Epoch: 290	Train Loss: 0.192170	Val Loss: 0.757904
# Train Epoch: 300	Train Loss: 0.208511	Val Loss: 0.767739
# Train Epoch: 310	Train Loss: 0.207369	Val Loss: 0.811110
# Train Epoch: 320	Train Loss: 0.231396	Val Loss: 0.813226
# Train Epoch: 330	Train Loss: 0.138688	Val Loss: 0.849988
# Train Epoch: 340	Train Loss: 0.118333	Val Loss: 0.858611
# Train Epoch: 350	Train Loss: 0.111351	Val Loss: 0.886460
# Train Epoch: 360	Train Loss: 0.110523	Val Loss: 0.919319
# Train Epoch: 370	Train Loss: 0.093072	Val Loss: 0.931292
# Train Epoch: 380	Train Loss: 0.090029	Val Loss: 0.975159
# Train Epoch: 390	Train Loss: 0.075606	Val Loss: 1.029605
# Train Epoch: 400	Train Loss: 0.064340	Val Loss: 1.056468
# Train Epoch: 410	Train Loss: 0.045867	Val Loss: 1.080880
# Train Epoch: 420	Train Loss: 0.047245	Val Loss: 1.113423
# Train Epoch: 430	Train Loss: 0.039366	Val Loss: 1.164801
# Train Epoch: 440	Train Loss: 0.030745	Val Loss: 1.200416
# Train Epoch: 450	Train Loss: 0.030910	Val Loss: 1.190307
# Train Epoch: 460	Train Loss: 0.022009	Val Loss: 1.280213
# Train Epoch: 470	Train Loss: 0.019178	Val Loss: 1.314370
# Train Epoch: 480	Train Loss: 0.018622	Val Loss: 1.364503
# Train Epoch: 490	Train Loss: 0.016777	Val Loss: 1.390993
# Train Epoch: 500	Train Loss: 0.012407	Val Loss: 1.406734
# Train Epoch: 510	Train Loss: 0.010664	Val Loss: 1.447496
# Train Epoch: 520	Train Loss: 0.012707	Val Loss: 1.470012
# Train Epoch: 530	Train Loss: 0.008579	Val Loss: 1.509636
# Train Epoch: 540	Train Loss: 0.008985	Val Loss: 1.524691
# Train Epoch: 550	Train Loss: 0.008052	Val Loss: 1.570781
# Train Epoch: 560	Train Loss: 0.009679	Val Loss: 1.598920
# Train Epoch: 570	Train Loss: 0.006415	Val Loss: 1.644112
# Train Epoch: 580	Train Loss: 0.004986	Val Loss: 1.659561
# Train Epoch: 590	Train Loss: 0.005641	Val Loss: 1.684029
# Train Epoch: 600	Train Loss: 0.004972	Val Loss: 1.702217

# %%
plt.figure(figsize=(16,9))
plt.plot(epoch_train_loss, c='b', label='Train loss')
plt.plot(epoch_val_loss, c='r', label = 'Validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('Loss', fontsize=20)
# Out:
# Text(0, 0.5, 'Loss')
